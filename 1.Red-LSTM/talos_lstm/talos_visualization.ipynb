# %%
import talos
import matplotlib as mlp
# Out:
# Using TensorFlow backend.

# %%
r = talos.Analyze('121220095319.csv')
plot = r.plot_line('val_acc')
r.plot_kde('val_acc')
r.plot_line('loss')
r.plot_kde('loss')
# Out:
# findfont: Font family ['Verdana'] not found. Falling back to DejaVu Sans.
