# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import json

# %%
landmarks_file = './01_02__outside_talking_still_laughing__YVGY8LOK.json'
with open(landmarks_file, "r") as read_file:
    data = json.load(read_file)

# %%
# for image, landmarks in data.items():    
#     plt.figure()
#     imgplot = plt.imshow(mpimg.imread(image))
#     for point in landmarks:
#         point[0] = np.interp(point[0],[0,1920],[-1,1])
#         point[1] = np.interp(point[0],[0,1080],[-1,1])
#         plt.plot(point[0], point[1], marker='.', markersize=3, color='red')
image, landmarks = list(data.items())[250]
plt.figure()
plt.plot(0, 0, marker='.', markersize=1, color="white")
plt.plot(1920, 1080, marker='.', markersize=1, color="white")
print(image)
for i,point in enumerate(landmarks):
    plt.plot(point[0], point[1], marker='.', markersize=1, color="black")
plt.axis("off")
# imgplot = plt.imshow(mpimg.imread(image))
plt.savefig('testplot.png', bbox_inches='tight')
# Out:
# /media/dadepe/Elements/frames/fake/01_02__outside_talking_still_laughing__YVGY8LOK/frame207.jpg
