# %%
import matplotlib.pyplot as plt

# %%
results = {
    'opencv' : 63.2732/314,
    'ssd' : 29.0582/68,
    'dlib': 606.2196/482,
    'mtcnn': 649.8856/502,
}

plot = plt.bar(list(results.keys()), results.values(), color='g')
plt.title('Tiempos de Ejecución por Modelo')
plt.xlabel('Modelos')
plt.ylabel('segundos')
# Out:
# Text(0, 0.5, 'segundos')
